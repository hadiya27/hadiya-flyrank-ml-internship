# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hadiya27/hadiya-flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *My lane: Refresh / Content Opportunity Scoring. I chose this lane because I want to investigate which pages should be reviewed first for possible refresh, expansion, protection, pruning, or monitoring. This connects the data to a practical content decision and allows the results to support a ranked review list rather than simply training a model*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *The decision is which pages should be reviewed first for a possible content action. A content reviewer would use the ranking to decide whether a page should be refreshed, expanded, protected, pruned, or monitored. A wrong recommendation could waste time and resources on a page that did not need attention, while missing a page that needed review could mean missing an opportunity to improve its performance*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

file_path = "hadiya-flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(file_path)

print("Number of rows:", len(df))
print("Average impressions_90d:", df["impressions_90d"].mean())
print("Average ctr:", df["ctr"].mean())
# Out:
# Number of rows: 30000
# Average impressions_90d: 5200.3663
# Average ctr: 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *My work will use observed data to identify directional patterns that may help with content-refresh decisions. The results can be used as decision-support to prioritize pages for review or updating. I can report measured relationships and observed patterns in the dataset, but I cannot claim that the analysis proves causation or predicts Google's algorithm. The results will not prove that a particular change will cause rankings or traffic to increase.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
